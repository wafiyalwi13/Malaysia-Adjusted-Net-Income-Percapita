# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Malaysia - Adjusted Net Income Per Capita.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    51 non-null     int64
#  1   Income  51 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 948.0 bytes

# %%
data.tail(5)
# Out:
#     Year       Income
# 46  2016  6853.014163
# 47  2017  7022.551186
# 48  2018  7586.466073
# 49  2019  7836.207596
# 50  2020  7277.201917

# %%
data.dtypes
# Out:
# Year        int64
# Income    float64
# dtype: object

# %%
sns.scatterplot(x="Year", y='Income', data=data, hue="Year")
# Out:
# <Axes: xlabel='Year', ylabel='Income'>

# %%
sns.regplot(x='Year', y='Income', data=data)
# Out:
# <Axes: xlabel='Year', ylabel='Income'>

# %%
lri = LinearRegression()

# %%
lri.fit(data[['Year']].values, data.Income)
# Out:
# LinearRegression()

# %%
lri.predict([[2021]])
# Out:
# array([7262.82310155])
